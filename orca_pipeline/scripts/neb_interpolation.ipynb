# %% [markdown]
# samll notebook to anlyze neb .interp files One needs to cleanup the file and rename it to neb_interpolation.txt

# %%
import numpy as np 
import seaborn as sns

# %%
data = np.loadtxt('neb_interpolation.txt' )
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = np.loadtxt('neb_interpolation.txt' )
#       2 data
#
# File ~/miniforge3/envs/aroma/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# ...
